# %%
# %matplotlib
import tkinter as tk
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gs
import wave
from mpl_toolkits import mplot3d
# Out:
# Using matplotlib backend: Qt5Agg

# %%
CWT = tk.Tk()
CWT.title('Project ASN')
# Out:
# ''

# %%
data_1 = pd.DataFrame()
ndata = 0

# %%
def clicked1():
    global data_1, ndata, duration
    with wave.open('Subjek 1.wav', 'rb') as wav_file:
        fs = wav_file.getframerate()  # Get the sampling frequency
        num_frames = wav_file.getnframes()  # Get the number of frames
        duration = num_frames / fs  # Calculate the duration of the audio signal
        time = np.linspace(0, duration, num_frames)  # Create a time array

        print("frekuensi sampling:", fs)
        print("banyaknya sample:", num_frames)
        print("lama durasi:", duration)

        frames = wav_file.readframes(num_frames)  # Read the frames as bytes
        amplitude = np.frombuffer(frames, dtype='int16')  # Convert the bytes to integers
        amplitude_left = amplitude[0::2]  # Extract the left channel (even indices)

    data_1 = pd.DataFrame({'y': amplitude_left, 'x': time})
    ndata = len(data_1)
    print(f"Loaded data shape: {data_1.shape}")
    print(f"Number of frames: {num_frames}")
    
def clicked2():
    global data_1, ndata, duration
    with wave.open('Subjek 2.wav', 'rb') as wav_file:
        fs = wav_file.getframerate()  # Get the sampling frequency
        num_frames = wav_file.getnframes()  # Get the number of frames
        duration = num_frames / fs  # Calculate the duration of the audio signal
        time = np.linspace(0, duration, num_frames)  # Create a time array

        print("frekuensi sampling:", fs)
        print("banyaknya sample:", num_frames)
        print("lama durasi:", duration)

        frames = wav_file.readframes(num_frames)  # Read the frames as bytes
        amplitude = np.frombuffer(frames, dtype='int16')  # Convert the bytes to integers
        amplitude_left = amplitude[0::2]  # Extract the left channel (even indices)

    data_1 = pd.DataFrame({'y': amplitude_left, 'x': time})
    ndata = len(data_1)
    print(f"Loaded data shape: {data_1.shape}")
    print(f"Number of frames: {num_frames}")


def clicked3():
    global data_1, ndata, duration
    with wave.open('Subjek 3.wav', 'rb') as wav_file:
        fs = wav_file.getframerate()  # Get the sampling frequency
        num_frames = wav_file.getnframes()  # Get the number of frames
        duration = num_frames / fs  # Calculate the duration of the audio signal
        time = np.linspace(0, duration, num_frames)  # Create a time array

        print("frekuensi sampling:", fs)
        print("banyaknya sample:", num_frames)
        print("lama durasi:", duration)

        frames = wav_file.readframes(num_frames)  # Read the frames as bytes
        amplitude = np.frombuffer(frames, dtype='int16')  # Convert the bytes to integers
        amplitude_left = amplitude[0::2]  # Extract the left channel (even indices)

    data_1 = pd.DataFrame({'y': amplitude_left, 'x': time})
    ndata = len(data_1)
    print(f"Loaded data shape: {data_1.shape}")
    print(f"Number of frames: {num_frames}")

def clicked4():
    global data_1, ndata, duration
    with wave.open('Subjek 4.wav', 'rb') as wav_file:
        fs = wav_file.getframerate()  # Get the sampling frequency
        num_frames = wav_file.getnframes()  # Get the number of frames
        duration = num_frames / fs  # Calculate the duration of the audio signal
        time = np.linspace(0, duration, num_frames)  # Create a time array

        print("frekuensi sampling:", fs)
        print("banyaknya sample:", num_frames)
        print("lama durasi:", duration)

        frames = wav_file.readframes(num_frames)  # Read the frames as bytes
        amplitude = np.frombuffer(frames, dtype='int16')  # Convert the bytes to integers
        amplitude_left = amplitude[0::2]  # Extract the left channel (even indices)

    data_1 = pd.DataFrame({'y': amplitude_left, 'x': time})
    ndata = len(data_1)
    print(f"Loaded data shape: {data_1.shape}")
    print(f"Number of frames: {num_frames}")

def clicked5():
    global data_1, ndata, duration
    with wave.open('Subjek 5.wav', 'rb') as wav_file:
        fs = wav_file.getframerate()  # Get the sampling frequency
        num_frames = wav_file.getnframes()  # Get the number of frames
        duration = num_frames / fs  # Calculate the duration of the audio signal
        time = np.linspace(0, duration, num_frames)  # Create a time array

        print("frekuensi sampling:", fs)
        print("banyaknya sample:", num_frames)
        print("lama durasi:", duration)

        frames = wav_file.readframes(num_frames)  # Read the frames as bytes
        amplitude = np.frombuffer(frames, dtype='int16')  # Convert the bytes to integers
        amplitude_left = amplitude[0::2]  # Extract the left channel (even indices)

    data_1 = pd.DataFrame({'y': amplitude_left, 'x': time})
    ndata = len(data_1)
    print(f"Loaded data shape: {data_1.shape}")
    print(f"Number of frames: {num_frames}")
    

def clicked6():
    global data_1, ndata, duration
    with wave.open('Subjek 6.wav', 'rb') as wav_file:
        fs = wav_file.getframerate()  # Get the sampling frequency
        num_frames = wav_file.getnframes()  # Get the number of frames
        duration = num_frames / fs  # Calculate the duration of the audio signal
        time = np.linspace(0, duration, num_frames)  # Create a time array

        print("frekuensi sampling:", fs)
        print("banyaknya sample:", num_frames)
        print("lama durasi:", duration)

        frames = wav_file.readframes(num_frames)  # Read the frames as bytes
        amplitude = np.frombuffer(frames, dtype='int16')  # Convert the bytes to integers
        amplitude_left = amplitude[0::2]  # Extract the left channel (even indices)

    data_1 = pd.DataFrame({'y': amplitude_left, 'x': time})
    ndata = len(data_1)
    print(f"Loaded data shape: {data_1.shape}")
    print(f"Number of frames: {num_frames}")
    
def clicked7():
    global data_1, ndata, duration
    with wave.open('Subjek 7.wav', 'rb') as wav_file:
        fs = wav_file.getframerate()  # Get the sampling frequency
        num_frames = wav_file.getnframes()  # Get the number of frames
        duration = num_frames / fs  # Calculate the duration of the audio signal
        time = np.linspace(0, duration, num_frames)  # Create a time array

        print("frekuensi sampling:", fs)
        print("banyaknya sample:", num_frames)
        print("lama durasi:", duration)

        frames = wav_file.readframes(num_frames)  # Read the frames as bytes
        amplitude = np.frombuffer(frames, dtype='int16')  # Convert the bytes to integers
        amplitude_left = amplitude[0::2]  # Extract the left channel (even indices)

    data_1 = pd.DataFrame({'y': amplitude_left, 'x': time})
    ndata = len(data_1)
    print(f"Loaded data shape: {data_1.shape}")
    print(f"Number of frames: {num_frames}")
    
def clicked8():
    global data_1, ndata, duration
    with wave.open('Subjek 8.wav', 'rb') as wav_file:
        fs = wav_file.getframerate()  # Get the sampling frequency
        num_frames = wav_file.getnframes()  # Get the number of frames
        duration = num_frames / fs  # Calculate the duration of the audio signal
        time = np.linspace(0, duration, num_frames)  # Create a time array

        print("frekuensi sampling:", fs)
        print("banyaknya sample:", num_frames)
        print("lama durasi:", duration)

        frames = wav_file.readframes(num_frames)  # Read the frames as bytes
        amplitude = np.frombuffer(frames, dtype='int16')  # Convert the bytes to integers
        amplitude_left = amplitude[0::2]  # Extract the left channel (even indices)

    data_1 = pd.DataFrame({'y': amplitude_left, 'x': time})
    ndata = len(data_1)
    print(f"Loaded data shape: {data_1.shape}")
    print(f"Number of frames: {num_frames}")
    
def clicked9():
    global data_1, ndata, duration
    with wave.open('Subjek 9.wav', 'rb') as wav_file:
        fs = wav_file.getframerate()  # Get the sampling frequency
        num_frames = wav_file.getnframes()  # Get the number of frames
        duration = num_frames / fs  # Calculate the duration of the audio signal
        time = np.linspace(0, duration, num_frames)  # Create a time array

        print("frekuensi sampling:", fs)
        print("banyaknya sample:", num_frames)
        print("lama durasi:", duration)

        frames = wav_file.readframes(num_frames)  # Read the frames as bytes
        amplitude = np.frombuffer(frames, dtype='int16')  # Convert the bytes to integers
        amplitude_left = amplitude[0::2]  # Extract the left channel (even indices)

    data_1 = pd.DataFrame({'y': amplitude_left, 'x': time})
    ndata = len(data_1)
    print(f"Loaded data shape: {data_1.shape}")
    print(f"Number of frames: {num_frames}")
    
def clicked10():
    global data_1, ndata, duration
    with wave.open('Subjek 10.wav', 'rb') as wav_file:
        fs = wav_file.getframerate()  # Get the sampling frequency
        num_frames = wav_file.getnframes()  # Get the number of frames
        duration = num_frames / fs  # Calculate the duration of the audio signal
        time = np.linspace(0, duration, num_frames)  # Create a time array

        print("frekuensi sampling:", fs)
        print("banyaknya sample:", num_frames)
        print("lama durasi:", duration)

        frames = wav_file.readframes(num_frames)  # Read the frames as bytes
        amplitude = np.frombuffer(frames, dtype='int16')  # Convert the bytes to integers
        amplitude_left = amplitude[0::2]  # Extract the left channel (even indices)

    data_1 = pd.DataFrame({'y': amplitude_left, 'x': time})
    ndata = len(data_1)
    print(f"Loaded data shape: {data_1.shape}")
    print(f"Number of frames: {num_frames}")

# %%
clicked1()
clicked2()
clicked3()
clicked4()
clicked5()
clicked6()
clicked7()
clicked8()
clicked9()
clicked10()
# Out:
# frekuensi sampling: 8000
# banyaknya sample: 66629
# lama durasi: 8.328625
# Loaded data shape: (66629, 2)
# Number of frames: 66629
# frekuensi sampling: 8000
# banyaknya sample: 68277
# lama durasi: 8.534625
# Loaded data shape: (68277, 2)
# Number of frames: 68277
# frekuensi sampling: 8000
# banyaknya sample: 68336
# lama durasi: 8.542
# Loaded data shape: (68336, 2)
# Number of frames: 68336
# frekuensi sampling: 8000
# banyaknya sample: 69955
# lama durasi: 8.744375
# Loaded data shape: (69955, 2)
# Number of frames: 69955
# frekuensi sampling: 8000
# banyaknya sample: 64624
# lama durasi: 8.078
# Loaded data shape: (64624, 2)
# Number of frames: 64624
# frekuensi sampling: 8000
# banyaknya sample: 65008
# lama durasi: 8.126
# Loaded data shape: (65008, 2)
# Number of frames: 65008
# frekuensi sampling: 8000
# banyaknya sample: 65105
# lama durasi: 8.138125
# Loaded data shape: (65105, 2)
# Number of frames: 65105
# frekuensi sampling: 8000
# banyaknya sample: 69299
# lama durasi: 8.662375
# Loaded data shape: (69299, 2)
# Number of frames: 69299
# frekuensi sampling: 8000
# banyaknya sample: 66969
# lama durasi: 8.371125
# Loaded data shape: (66969, 2)
# Number of frames: 66969
# frekuensi sampling: 8000
# banyaknya sample: 63331
# lama durasi: 7.916375
# Loaded data shape: (63331, 2)
# Number of frames: 63331

# %%
row = 100
column = 100

# %%
def cwt(signal, wavelet, a0, b0, da):

    ndata = len(signal)

    dt= 1/8000; #fs = 1000
    t = np.arange(0, dt*ndata, dt)
    
    f0=0.849 #frekuensi center
    w0 = 2 * np.pi * f0
    db = (ndata -1)*dt/column
    cwt = np.zeros((row, column))

    a = a0
    for i in range(row):
        b = b0
        for j in range(column):
            real, imaj = wavelet(t, a, b, w0)
            real_cwt = np.sum(np.multiply(signal, real))
            imaj_cwt = np.sum(np.multiply(signal, imaj))
            cwt[i, j] = (np.sqrt(real_cwt**2 + imaj_cwt**2))
            b += db
        a += da
    fc = f0
    
    fk_values = []
    tk_values = []
    
    for i in range(1, row + 1):
        fk = fc / (a0 + (i * da))
        tk = (data_1['x'][ndata - 1] / column) * i
        
        fk = round(fk, 3)  # Membulatkan fk menjadi 3 angka di belakang koma
        tk = round(tk, 3)
        fk_values.append(fk)
        tk_values.append(tk)
        print(f"skala[{i}] = {fk} Hz, waktu[{i}] = {tk} s")
    
    
    return cwt, fk_values, tk_values

# %%
def morlet_complex(t, a, b, w0):
    real = 1/np.sqrt(a) * 1/(np.pi**0.25) * np.exp(-(t-b)/a*(t-b)/a/2.0) * np.cos(w0*(t-b)/a)
    imaj = 1/np.sqrt(a) * -1/(np.pi**0.25) * np.exp(-(t-b)/a*(t-b)/a/2.0) * np.sin(w0*(t-b)/a)
    return real, imaj

# %%
def main():
    fig1 = plt.figure(figsize=(15, 6))  # Figur untuk ax1 dan ax3
    fig2 = plt.figure(figsize=(20, 10))  # Figur untuk ax2

    gs1 = gs.GridSpec(3, 1, figure=fig1)  # GridSpec untuk fig1
    gs2 = gs.GridSpec(1, 1, figure=fig2)  # GridSpec untuk fig2

    ax1 = fig1.add_subplot(gs1[0:1, 0])  # Ax1 menggunakan baris pertama (indeks 0) dan kolom pertama (indeks 0)
    ax3 = fig1.add_subplot(gs1[1:, 0], projection="3d")  # Ax3 menggunakan baris kedua hingga ketiga (indeks 1 hingga 2) dan kolom pertama (indeks 0)
    ax2 = fig2.add_subplot(gs2[0, 0])  # Ax2 menggunakan baris pertama (indeks 0) dan kolom pertama (indeks 0)
    
    
    data_1.plot(ax=ax1, x='x', y='y', legend=False, grid=True)
    dt = 1/8000;

    a = float(ent_s.get())#0.0001 #Scallng #(10-4)
    b = (ndata-1)*dt/column
    #b = 4
    da = float(ent_ds.get())#0.0009 #Step Scale #(10-4)

    data1_numpy = data_1['y'].to_numpy()
    result_cwt, fk_values, tk_values = cwt(data1_numpy, morlet_complex, a, b, da)
    # print(np.array(result_cwt).shape)
    
    plot_y = fk_values
    plot_x = tk_values
    xx, yy = np.meshgrid(plot_x, plot_y)
    
    num_yticks = 50
    
    # indeks untuk setiap titik data yang akan ditampilkan labelnya
    y_indexes = np.linspace(0, len(plot_y) - 1, num_yticks, dtype=int)

    # label baru yang sesuai dengan indeks ini
    new_yticklabels = [plot_y[i] for i in y_indexes]

    # buat heatmap dengan label baru ini
    sns.heatmap(result_cwt, cmap='gist_rainbow', ax=ax2, xticklabels=plot_x)
            
    # set xticks and yticks positions to new indexes
    ax2.set_yticks(y_indexes)
    ax2.set_yticklabels(new_yticklabels)

    ax2.invert_yaxis()
    ax2.set_xlabel('Waktu')
    ax2.set_ylabel('Frekuensi')

    ax2.set_title('CWT Contour')
    


    #plt.show()
   
    #ax3.plot_surface(xx, yy, np.array(result_cwt), cmap='gist_rainbow')
    ax3.plot_surface(xx, yy, result_cwt, cmap='gist_rainbow')
    print(f'Jumlah Sample : {ndata}')    
    ymax = max(data_1['y'])
    ymin = min(data_1['y'])
    

    ax1.set_xlim(0, duration)
    ax1.set_ylim(ymin, ymax)
    ax1.set_xlabel('Time(ms)')
    ax1.set_ylabel('Amplitude(mV)')
    ax1.set_title('Input Signal')
    

    ax3.set_xlabel('Waktu')
    ax3.set_ylabel('Frekuensi')
    ax3.set_zlabel('Magnitude (Hz)')
    ax3.set_title('CWT 3D Surface')
    plt.tight_layout()
    plt.show()

# %%
r = tk.IntVar()
r.set(None)
label_s = tk.Label(CWT, text = 'Skala (S)').pack()
ent_s = tk.Entry(CWT)
ent_s.insert(tk.END,'0.0001')
ent_s.pack()
label_ds = tk.Label(CWT, text = 'Delta Skala (dS)').pack()
ent_ds = tk.Entry(CWT)
ent_ds.insert(tk.END,'0.0009')
ent_ds.pack()
label_signal = tk.Label(CWT, text = 'Choose a Signal:').pack()
rb1 = tk.Radiobutton(CWT, text='Subjek 1', variable=r, value=1, command=clicked1).pack()
rb1 = tk.Radiobutton(CWT, text='Subjek 2', variable=r, value=2, command=clicked2).pack()
rb1 = tk.Radiobutton(CWT, text='Subjek 3', variable=r, value=3, command=clicked3).pack()
rb1 = tk.Radiobutton(CWT, text='Subjek 4', variable=r, value=4, command=clicked4).pack()
rb1 = tk.Radiobutton(CWT, text='Subjek 5', variable=r, value=5, command=clicked5).pack()
rb1 = tk.Radiobutton(CWT, text='Subjek 6', variable=r, value=6, command=clicked6).pack()
rb1 = tk.Radiobutton(CWT, text='Subjek 7', variable=r, value=7, command=clicked7).pack()
rb1 = tk.Radiobutton(CWT, text='Subjek 8', variable=r, value=8, command=clicked8).pack()
rb1 = tk.Radiobutton(CWT, text='Subjek 9', variable=r, value=9, command=clicked9).pack()
rb1 = tk.Radiobutton(CWT, text='Subjek 10', variable=r, value=10, command=clicked10).pack()
button = tk.Button(text='Plot 3D and Contour', command=main).pack()
CWT.mainloop()
# Out:
# frekuensi sampling: 8000
# banyaknya sample: 65105
# lama durasi: 8.138125
# Loaded data shape: (65105, 2)
# Number of frames: 65105
# skala[1] = 849.0 Hz, waktu[1] = 0.081 s
# skala[2] = 446.842 Hz, waktu[2] = 0.163 s
# skala[3] = 303.214 Hz, waktu[3] = 0.244 s
# skala[4] = 229.459 Hz, waktu[4] = 0.326 s
# skala[5] = 184.565 Hz, waktu[5] = 0.407 s
# skala[6] = 154.364 Hz, waktu[6] = 0.488 s
# skala[7] = 132.656 Hz, waktu[7] = 0.57 s
# skala[8] = 116.301 Hz, waktu[8] = 0.651 s
# skala[9] = 103.537 Hz, waktu[9] = 0.732 s
# skala[10] = 93.297 Hz, waktu[10] = 0.814 s
# skala[11] = 84.9 Hz, waktu[11] = 0.895 s
# skala[12] = 77.89 Hz, waktu[12] = 0.977 s
# skala[13] = 71.949 Hz, waktu[13] = 1.058 s
# skala[14] = 66.85 Hz, waktu[14] = 1.139 s
# skala[15] = 62.426 Hz, waktu[15] = 1.221 s
# skala[16] = 58.552 Hz, waktu[16] = 1.302 s
# skala[17] = 55.13 Hz, waktu[17] = 1.383 s
# skala[18] = 52.086 Hz, waktu[18] = 1.465 s
# skala[19] = 49.36 Hz, waktu[19] = 1.546 s
# skala[20] = 46.906 Hz, waktu[20] = 1.628 s
# skala[21] = 44.684 Hz, waktu[21] = 1.709 s
# skala[22] = 42.663 Hz, waktu[22] = 1.79 s
# skala[23] = 40.817 Hz, waktu[23] = 1.872 s
# skala[24] = 39.124 Hz, waktu[24] = 1.953 s
# skala[25] = 37.566 Hz, waktu[25] = 2.035 s
# skala[26] = 36.128 Hz, waktu[26] = 2.116 s
# skala[27] = 34.795 Hz, waktu[27] = 2.197 s
# skala[28] = 33.557 Hz, waktu[28] = 2.279 s
# skala[29] = 32.405 Hz, waktu[29] = 2.36 s
# skala[30] = 31.328 Hz, waktu[30] = 2.441 s
# skala[31] = 30.321 Hz, waktu[31] = 2.523 s
# skala[32] = 29.377 Hz, waktu[32] = 2.604 s
# skala[33] = 28.49 Hz, waktu[33] = 2.686 s
# skala[34] = 27.655 Hz, waktu[34] = 2.767 s
# skala[35] = 26.867 Hz, waktu[35] = 2.848 s
# skala[36] = 26.123 Hz, waktu[36] = 2.93 s
# skala[37] = 25.419 Hz, waktu[37] = 3.011 s
# skala[38] = 24.752 Hz, waktu[38] = 3.092 s
# skala[39] = 24.119 Hz, waktu[39] = 3.174 s
# skala[40] = 23.518 Hz, waktu[40] = 3.255 s
# skala[41] = 22.946 Hz, waktu[41] = 3.337 s
# skala[42] = 22.401 Hz, waktu[42] = 3.418 s
# skala[43] = 21.881 Hz, waktu[43] = 3.499 s
# skala[44] = 21.385 Hz, waktu[44] = 3.581 s
# skala[45] = 20.911 Hz, waktu[45] = 3.662 s
# skala[46] = 20.458 Hz, waktu[46] = 3.744 s
# skala[47] = 20.024 Hz, waktu[47] = 3.825 s
# skala[48] = 19.607 Hz, waktu[48] = 3.906 s
# skala[49] = 19.208 Hz, waktu[49] = 3.988 s
# skala[50] = 18.825 Hz, waktu[50] = 4.069 s
# skala[51] = 18.457 Hz, waktu[51] = 4.15 s
# skala[52] = 18.102 Hz, waktu[52] = 4.232 s
# skala[53] = 17.762 Hz, waktu[53] = 4.313 s
# skala[54] = 17.433 Hz, waktu[54] = 4.395 s
# skala[55] = 17.117 Hz, waktu[55] = 4.476 s
# skala[56] = 16.812 Hz, waktu[56] = 4.557 s
# skala[57] = 16.518 Hz, waktu[57] = 4.639 s
# skala[58] = 16.233 Hz, waktu[58] = 4.72 s
# skala[59] = 15.959 Hz, waktu[59] = 4.801 s
# skala[60] = 15.693 Hz, waktu[60] = 4.883 s
# skala[61] = 15.436 Hz, waktu[61] = 4.964 s
# skala[62] = 15.188 Hz, waktu[62] = 5.046 s
# skala[63] = 14.947 Hz, waktu[63] = 5.127 s
# skala[64] = 14.714 Hz, waktu[64] = 5.208 s
# skala[65] = 14.488 Hz, waktu[65] = 5.29 s
# skala[66] = 14.269 Hz, waktu[66] = 5.371 s
# skala[67] = 14.056 Hz, waktu[67] = 5.453 s
# skala[68] = 13.85 Hz, waktu[68] = 5.534 s
# skala[69] = 13.65 Hz, waktu[69] = 5.615 s
# skala[70] = 13.455 Hz, waktu[70] = 5.697 s
# skala[71] = 13.266 Hz, waktu[71] = 5.778 s
# skala[72] = 13.082 Hz, waktu[72] = 5.859 s
# skala[73] = 12.903 Hz, waktu[73] = 5.941 s
# skala[74] = 12.729 Hz, waktu[74] = 6.022 s
# skala[75] = 12.559 Hz, waktu[75] = 6.104 s
# skala[76] = 12.394 Hz, waktu[76] = 6.185 s
# skala[77] = 12.233 Hz, waktu[77] = 6.266 s
# skala[78] = 12.077 Hz, waktu[78] = 6.348 s
# skala[79] = 11.924 Hz, waktu[79] = 6.429 s
# skala[80] = 11.775 Hz, waktu[80] = 6.51 s
# skala[81] = 11.63 Hz, waktu[81] = 6.592 s
# skala[82] = 11.488 Hz, waktu[82] = 6.673 s
# skala[83] = 11.35 Hz, waktu[83] = 6.755 s
# skala[84] = 11.215 Hz, waktu[84] = 6.836 s
# skala[85] = 11.084 Hz, waktu[85] = 6.917 s
# skala[86] = 10.955 Hz, waktu[86] = 6.999 s
# skala[87] = 10.829 Hz, waktu[87] = 7.08 s
# skala[88] = 10.706 Hz, waktu[88] = 7.162 s
# skala[89] = 10.586 Hz, waktu[89] = 7.243 s
# skala[90] = 10.469 Hz, waktu[90] = 7.324 s
# skala[91] = 10.354 Hz, waktu[91] = 7.406 s
# skala[92] = 10.241 Hz, waktu[92] = 7.487 s
# skala[93] = 10.131 Hz, waktu[93] = 7.568 s
# skala[94] = 10.024 Hz, waktu[94] = 7.65 s
# skala[95] = 9.918 Hz, waktu[95] = 7.731 s
# skala[96] = 9.815 Hz, waktu[96] = 7.813 s
# skala[97] = 9.714 Hz, waktu[97] = 7.894 s
# skala[98] = 9.615 Hz, waktu[98] = 7.975 s
# skala[99] = 9.518 Hz, waktu[99] = 8.057 s
# skala[100] = 9.423 Hz, waktu[100] = 8.138 s
# Jumlah Sample : 65105
# frekuensi sampling: 8000
# banyaknya sample: 69299
# lama durasi: 8.662375
# Loaded data shape: (69299, 2)
# Number of frames: 69299
# skala[1] = 849.0 Hz, waktu[1] = 0.087 s
# skala[2] = 446.842 Hz, waktu[2] = 0.173 s
# skala[3] = 303.214 Hz, waktu[3] = 0.26 s
# skala[4] = 229.459 Hz, waktu[4] = 0.346 s
# skala[5] = 184.565 Hz, waktu[5] = 0.433 s
# skala[6] = 154.364 Hz, waktu[6] = 0.52 s
# skala[7] = 132.656 Hz, waktu[7] = 0.606 s
# skala[8] = 116.301 Hz, waktu[8] = 0.693 s
# skala[9] = 103.537 Hz, waktu[9] = 0.78 s
# skala[10] = 93.297 Hz, waktu[10] = 0.866 s
# skala[11] = 84.9 Hz, waktu[11] = 0.953 s
# skala[12] = 77.89 Hz, waktu[12] = 1.039 s
# skala[13] = 71.949 Hz, waktu[13] = 1.126 s
# skala[14] = 66.85 Hz, waktu[14] = 1.213 s
# skala[15] = 62.426 Hz, waktu[15] = 1.299 s
# skala[16] = 58.552 Hz, waktu[16] = 1.386 s
# skala[17] = 55.13 Hz, waktu[17] = 1.473 s
# skala[18] = 52.086 Hz, waktu[18] = 1.559 s
# skala[19] = 49.36 Hz, waktu[19] = 1.646 s
# skala[20] = 46.906 Hz, waktu[20] = 1.732 s
# skala[21] = 44.684 Hz, waktu[21] = 1.819 s
# skala[22] = 42.663 Hz, waktu[22] = 1.906 s
# skala[23] = 40.817 Hz, waktu[23] = 1.992 s
# skala[24] = 39.124 Hz, waktu[24] = 2.079 s
# skala[25] = 37.566 Hz, waktu[25] = 2.166 s
# skala[26] = 36.128 Hz, waktu[26] = 2.252 s
# skala[27] = 34.795 Hz, waktu[27] = 2.339 s
# skala[28] = 33.557 Hz, waktu[28] = 2.425 s
# skala[29] = 32.405 Hz, waktu[29] = 2.512 s
# skala[30] = 31.328 Hz, waktu[30] = 2.599 s
# skala[31] = 30.321 Hz, waktu[31] = 2.685 s
# skala[32] = 29.377 Hz, waktu[32] = 2.772 s
# skala[33] = 28.49 Hz, waktu[33] = 2.859 s
# skala[34] = 27.655 Hz, waktu[34] = 2.945 s
# skala[35] = 26.867 Hz, waktu[35] = 3.032 s
# skala[36] = 26.123 Hz, waktu[36] = 3.118 s
# skala[37] = 25.419 Hz, waktu[37] = 3.205 s
# skala[38] = 24.752 Hz, waktu[38] = 3.292 s
# skala[39] = 24.119 Hz, waktu[39] = 3.378 s
# skala[40] = 23.518 Hz, waktu[40] = 3.465 s
# skala[41] = 22.946 Hz, waktu[41] = 3.552 s
# skala[42] = 22.401 Hz, waktu[42] = 3.638 s
# skala[43] = 21.881 Hz, waktu[43] = 3.725 s
# skala[44] = 21.385 Hz, waktu[44] = 3.811 s
# skala[45] = 20.911 Hz, waktu[45] = 3.898 s
# skala[46] = 20.458 Hz, waktu[46] = 3.985 s
# skala[47] = 20.024 Hz, waktu[47] = 4.071 s
# skala[48] = 19.607 Hz, waktu[48] = 4.158 s
# skala[49] = 19.208 Hz, waktu[49] = 4.245 s
# skala[50] = 18.825 Hz, waktu[50] = 4.331 s
# skala[51] = 18.457 Hz, waktu[51] = 4.418 s
# skala[52] = 18.102 Hz, waktu[52] = 4.504 s
# skala[53] = 17.762 Hz, waktu[53] = 4.591 s
# skala[54] = 17.433 Hz, waktu[54] = 4.678 s
# skala[55] = 17.117 Hz, waktu[55] = 4.764 s
# skala[56] = 16.812 Hz, waktu[56] = 4.851 s
# skala[57] = 16.518 Hz, waktu[57] = 4.938 s
# skala[58] = 16.233 Hz, waktu[58] = 5.024 s
# skala[59] = 15.959 Hz, waktu[59] = 5.111 s
# skala[60] = 15.693 Hz, waktu[60] = 5.197 s
# skala[61] = 15.436 Hz, waktu[61] = 5.284 s
# skala[62] = 15.188 Hz, waktu[62] = 5.371 s
# skala[63] = 14.947 Hz, waktu[63] = 5.457 s
# skala[64] = 14.714 Hz, waktu[64] = 5.544 s
# skala[65] = 14.488 Hz, waktu[65] = 5.631 s
# skala[66] = 14.269 Hz, waktu[66] = 5.717 s
# skala[67] = 14.056 Hz, waktu[67] = 5.804 s
# skala[68] = 13.85 Hz, waktu[68] = 5.89 s
# skala[69] = 13.65 Hz, waktu[69] = 5.977 s
# skala[70] = 13.455 Hz, waktu[70] = 6.064 s
# skala[71] = 13.266 Hz, waktu[71] = 6.15 s
# skala[72] = 13.082 Hz, waktu[72] = 6.237 s
# skala[73] = 12.903 Hz, waktu[73] = 6.324 s
# skala[74] = 12.729 Hz, waktu[74] = 6.41 s
# skala[75] = 12.559 Hz, waktu[75] = 6.497 s
# skala[76] = 12.394 Hz, waktu[76] = 6.583 s
# skala[77] = 12.233 Hz, waktu[77] = 6.67 s
# skala[78] = 12.077 Hz, waktu[78] = 6.757 s
# skala[79] = 11.924 Hz, waktu[79] = 6.843 s
# skala[80] = 11.775 Hz, waktu[80] = 6.93 s
# skala[81] = 11.63 Hz, waktu[81] = 7.017 s
# skala[82] = 11.488 Hz, waktu[82] = 7.103 s
# skala[83] = 11.35 Hz, waktu[83] = 7.19 s
# skala[84] = 11.215 Hz, waktu[84] = 7.276 s
# skala[85] = 11.084 Hz, waktu[85] = 7.363 s
# skala[86] = 10.955 Hz, waktu[86] = 7.45 s
# skala[87] = 10.829 Hz, waktu[87] = 7.536 s
# skala[88] = 10.706 Hz, waktu[88] = 7.623 s
# skala[89] = 10.586 Hz, waktu[89] = 7.71 s
# skala[90] = 10.469 Hz, waktu[90] = 7.796 s
# skala[91] = 10.354 Hz, waktu[91] = 7.883 s
# skala[92] = 10.241 Hz, waktu[92] = 7.969 s
# skala[93] = 10.131 Hz, waktu[93] = 8.056 s
# skala[94] = 10.024 Hz, waktu[94] = 8.143 s
# skala[95] = 9.918 Hz, waktu[95] = 8.229 s
# skala[96] = 9.815 Hz, waktu[96] = 8.316 s
# skala[97] = 9.714 Hz, waktu[97] = 8.403 s
# skala[98] = 9.615 Hz, waktu[98] = 8.489 s
# skala[99] = 9.518 Hz, waktu[99] = 8.576 s
# skala[100] = 9.423 Hz, waktu[100] = 8.662 s
# Jumlah Sample : 69299
# frekuensi sampling: 8000
# banyaknya sample: 66969
# lama durasi: 8.371125
# Loaded data shape: (66969, 2)
# Number of frames: 66969
# skala[1] = 849.0 Hz, waktu[1] = 0.084 s
# skala[2] = 446.842 Hz, waktu[2] = 0.167 s
# skala[3] = 303.214 Hz, waktu[3] = 0.251 s
# skala[4] = 229.459 Hz, waktu[4] = 0.335 s
# skala[5] = 184.565 Hz, waktu[5] = 0.419 s
# skala[6] = 154.364 Hz, waktu[6] = 0.502 s
# skala[7] = 132.656 Hz, waktu[7] = 0.586 s
# skala[8] = 116.301 Hz, waktu[8] = 0.67 s
# skala[9] = 103.537 Hz, waktu[9] = 0.753 s
# skala[10] = 93.297 Hz, waktu[10] = 0.837 s
# skala[11] = 84.9 Hz, waktu[11] = 0.921 s
# skala[12] = 77.89 Hz, waktu[12] = 1.005 s
# skala[13] = 71.949 Hz, waktu[13] = 1.088 s
# skala[14] = 66.85 Hz, waktu[14] = 1.172 s
# skala[15] = 62.426 Hz, waktu[15] = 1.256 s
# skala[16] = 58.552 Hz, waktu[16] = 1.339 s
# skala[17] = 55.13 Hz, waktu[17] = 1.423 s
# skala[18] = 52.086 Hz, waktu[18] = 1.507 s
# skala[19] = 49.36 Hz, waktu[19] = 1.591 s
# skala[20] = 46.906 Hz, waktu[20] = 1.674 s
# skala[21] = 44.684 Hz, waktu[21] = 1.758 s
# skala[22] = 42.663 Hz, waktu[22] = 1.842 s
# skala[23] = 40.817 Hz, waktu[23] = 1.925 s
# skala[24] = 39.124 Hz, waktu[24] = 2.009 s
# skala[25] = 37.566 Hz, waktu[25] = 2.093 s
# skala[26] = 36.128 Hz, waktu[26] = 2.176 s
# skala[27] = 34.795 Hz, waktu[27] = 2.26 s
# skala[28] = 33.557 Hz, waktu[28] = 2.344 s
# skala[29] = 32.405 Hz, waktu[29] = 2.428 s
# skala[30] = 31.328 Hz, waktu[30] = 2.511 s
# skala[31] = 30.321 Hz, waktu[31] = 2.595 s
# skala[32] = 29.377 Hz, waktu[32] = 2.679 s
# skala[33] = 28.49 Hz, waktu[33] = 2.762 s
# skala[34] = 27.655 Hz, waktu[34] = 2.846 s
# skala[35] = 26.867 Hz, waktu[35] = 2.93 s
# skala[36] = 26.123 Hz, waktu[36] = 3.014 s
# skala[37] = 25.419 Hz, waktu[37] = 3.097 s
# skala[38] = 24.752 Hz, waktu[38] = 3.181 s
# skala[39] = 24.119 Hz, waktu[39] = 3.265 s
# skala[40] = 23.518 Hz, waktu[40] = 3.348 s
# skala[41] = 22.946 Hz, waktu[41] = 3.432 s
# skala[42] = 22.401 Hz, waktu[42] = 3.516 s
# skala[43] = 21.881 Hz, waktu[43] = 3.6 s
# skala[44] = 21.385 Hz, waktu[44] = 3.683 s
# skala[45] = 20.911 Hz, waktu[45] = 3.767 s
# skala[46] = 20.458 Hz, waktu[46] = 3.851 s
# skala[47] = 20.024 Hz, waktu[47] = 3.934 s
# skala[48] = 19.607 Hz, waktu[48] = 4.018 s
# skala[49] = 19.208 Hz, waktu[49] = 4.102 s
# skala[50] = 18.825 Hz, waktu[50] = 4.186 s
# skala[51] = 18.457 Hz, waktu[51] = 4.269 s
# skala[52] = 18.102 Hz, waktu[52] = 4.353 s
# skala[53] = 17.762 Hz, waktu[53] = 4.437 s
# skala[54] = 17.433 Hz, waktu[54] = 4.52 s
# skala[55] = 17.117 Hz, waktu[55] = 4.604 s
# skala[56] = 16.812 Hz, waktu[56] = 4.688 s
# skala[57] = 16.518 Hz, waktu[57] = 4.772 s
# skala[58] = 16.233 Hz, waktu[58] = 4.855 s
# skala[59] = 15.959 Hz, waktu[59] = 4.939 s
# skala[60] = 15.693 Hz, waktu[60] = 5.023 s
# skala[61] = 15.436 Hz, waktu[61] = 5.106 s
# skala[62] = 15.188 Hz, waktu[62] = 5.19 s
# skala[63] = 14.947 Hz, waktu[63] = 5.274 s
# skala[64] = 14.714 Hz, waktu[64] = 5.358 s
# skala[65] = 14.488 Hz, waktu[65] = 5.441 s
# skala[66] = 14.269 Hz, waktu[66] = 5.525 s
# skala[67] = 14.056 Hz, waktu[67] = 5.609 s
# skala[68] = 13.85 Hz, waktu[68] = 5.692 s
# skala[69] = 13.65 Hz, waktu[69] = 5.776 s
# skala[70] = 13.455 Hz, waktu[70] = 5.86 s
# skala[71] = 13.266 Hz, waktu[71] = 5.943 s
# skala[72] = 13.082 Hz, waktu[72] = 6.027 s
# skala[73] = 12.903 Hz, waktu[73] = 6.111 s
# skala[74] = 12.729 Hz, waktu[74] = 6.195 s
# skala[75] = 12.559 Hz, waktu[75] = 6.278 s
# skala[76] = 12.394 Hz, waktu[76] = 6.362 s
# skala[77] = 12.233 Hz, waktu[77] = 6.446 s
# skala[78] = 12.077 Hz, waktu[78] = 6.529 s
# skala[79] = 11.924 Hz, waktu[79] = 6.613 s
# skala[80] = 11.775 Hz, waktu[80] = 6.697 s
# skala[81] = 11.63 Hz, waktu[81] = 6.781 s
# skala[82] = 11.488 Hz, waktu[82] = 6.864 s
# skala[83] = 11.35 Hz, waktu[83] = 6.948 s
# skala[84] = 11.215 Hz, waktu[84] = 7.032 s
# skala[85] = 11.084 Hz, waktu[85] = 7.115 s
# skala[86] = 10.955 Hz, waktu[86] = 7.199 s
# skala[87] = 10.829 Hz, waktu[87] = 7.283 s
# skala[88] = 10.706 Hz, waktu[88] = 7.367 s
# skala[89] = 10.586 Hz, waktu[89] = 7.45 s
# skala[90] = 10.469 Hz, waktu[90] = 7.534 s
# skala[91] = 10.354 Hz, waktu[91] = 7.618 s
# skala[92] = 10.241 Hz, waktu[92] = 7.701 s
# skala[93] = 10.131 Hz, waktu[93] = 7.785 s
# skala[94] = 10.024 Hz, waktu[94] = 7.869 s
# skala[95] = 9.918 Hz, waktu[95] = 7.953 s
# skala[96] = 9.815 Hz, waktu[96] = 8.036 s
# skala[97] = 9.714 Hz, waktu[97] = 8.12 s
# skala[98] = 9.615 Hz, waktu[98] = 8.204 s
# skala[99] = 9.518 Hz, waktu[99] = 8.287 s
# skala[100] = 9.423 Hz, waktu[100] = 8.371 s
# Jumlah Sample : 66969
# frekuensi sampling: 8000
# banyaknya sample: 63331
# lama durasi: 7.916375
# Loaded data shape: (63331, 2)
# Number of frames: 63331
# skala[1] = 849.0 Hz, waktu[1] = 0.079 s
# skala[2] = 446.842 Hz, waktu[2] = 0.158 s
# skala[3] = 303.214 Hz, waktu[3] = 0.237 s
# skala[4] = 229.459 Hz, waktu[4] = 0.317 s
# skala[5] = 184.565 Hz, waktu[5] = 0.396 s
# skala[6] = 154.364 Hz, waktu[6] = 0.475 s
# skala[7] = 132.656 Hz, waktu[7] = 0.554 s
# skala[8] = 116.301 Hz, waktu[8] = 0.633 s
# skala[9] = 103.537 Hz, waktu[9] = 0.712 s
# skala[10] = 93.297 Hz, waktu[10] = 0.792 s
# skala[11] = 84.9 Hz, waktu[11] = 0.871 s
# skala[12] = 77.89 Hz, waktu[12] = 0.95 s
# skala[13] = 71.949 Hz, waktu[13] = 1.029 s
# skala[14] = 66.85 Hz, waktu[14] = 1.108 s
# skala[15] = 62.426 Hz, waktu[15] = 1.187 s
# skala[16] = 58.552 Hz, waktu[16] = 1.267 s
# skala[17] = 55.13 Hz, waktu[17] = 1.346 s
# skala[18] = 52.086 Hz, waktu[18] = 1.425 s
# skala[19] = 49.36 Hz, waktu[19] = 1.504 s
# skala[20] = 46.906 Hz, waktu[20] = 1.583 s
# skala[21] = 44.684 Hz, waktu[21] = 1.662 s
# skala[22] = 42.663 Hz, waktu[22] = 1.742 s
# skala[23] = 40.817 Hz, waktu[23] = 1.821 s
# skala[24] = 39.124 Hz, waktu[24] = 1.9 s
# skala[25] = 37.566 Hz, waktu[25] = 1.979 s
# skala[26] = 36.128 Hz, waktu[26] = 2.058 s
# skala[27] = 34.795 Hz, waktu[27] = 2.137 s
# skala[28] = 33.557 Hz, waktu[28] = 2.217 s
# skala[29] = 32.405 Hz, waktu[29] = 2.296 s
# skala[30] = 31.328 Hz, waktu[30] = 2.375 s
# skala[31] = 30.321 Hz, waktu[31] = 2.454 s
# skala[32] = 29.377 Hz, waktu[32] = 2.533 s
# skala[33] = 28.49 Hz, waktu[33] = 2.612 s
# skala[34] = 27.655 Hz, waktu[34] = 2.692 s
# skala[35] = 26.867 Hz, waktu[35] = 2.771 s
# skala[36] = 26.123 Hz, waktu[36] = 2.85 s
# skala[37] = 25.419 Hz, waktu[37] = 2.929 s
# skala[38] = 24.752 Hz, waktu[38] = 3.008 s
# skala[39] = 24.119 Hz, waktu[39] = 3.087 s
# skala[40] = 23.518 Hz, waktu[40] = 3.167 s
# skala[41] = 22.946 Hz, waktu[41] = 3.246 s
# skala[42] = 22.401 Hz, waktu[42] = 3.325 s
# skala[43] = 21.881 Hz, waktu[43] = 3.404 s
# skala[44] = 21.385 Hz, waktu[44] = 3.483 s
# skala[45] = 20.911 Hz, waktu[45] = 3.562 s
# skala[46] = 20.458 Hz, waktu[46] = 3.642 s
# skala[47] = 20.024 Hz, waktu[47] = 3.721 s
# skala[48] = 19.607 Hz, waktu[48] = 3.8 s
# skala[49] = 19.208 Hz, waktu[49] = 3.879 s
# skala[50] = 18.825 Hz, waktu[50] = 3.958 s
# skala[51] = 18.457 Hz, waktu[51] = 4.037 s
# skala[52] = 18.102 Hz, waktu[52] = 4.117 s
# skala[53] = 17.762 Hz, waktu[53] = 4.196 s
# skala[54] = 17.433 Hz, waktu[54] = 4.275 s
# skala[55] = 17.117 Hz, waktu[55] = 4.354 s
# skala[56] = 16.812 Hz, waktu[56] = 4.433 s
# skala[57] = 16.518 Hz, waktu[57] = 4.512 s
# skala[58] = 16.233 Hz, waktu[58] = 4.591 s
# skala[59] = 15.959 Hz, waktu[59] = 4.671 s
# skala[60] = 15.693 Hz, waktu[60] = 4.75 s
# skala[61] = 15.436 Hz, waktu[61] = 4.829 s
# skala[62] = 15.188 Hz, waktu[62] = 4.908 s
# skala[63] = 14.947 Hz, waktu[63] = 4.987 s
# skala[64] = 14.714 Hz, waktu[64] = 5.066 s
# skala[65] = 14.488 Hz, waktu[65] = 5.146 s
# skala[66] = 14.269 Hz, waktu[66] = 5.225 s
# skala[67] = 14.056 Hz, waktu[67] = 5.304 s
# skala[68] = 13.85 Hz, waktu[68] = 5.383 s
# skala[69] = 13.65 Hz, waktu[69] = 5.462 s
# skala[70] = 13.455 Hz, waktu[70] = 5.541 s
# skala[71] = 13.266 Hz, waktu[71] = 5.621 s
# skala[72] = 13.082 Hz, waktu[72] = 5.7 s
# skala[73] = 12.903 Hz, waktu[73] = 5.779 s
# skala[74] = 12.729 Hz, waktu[74] = 5.858 s
# skala[75] = 12.559 Hz, waktu[75] = 5.937 s
# skala[76] = 12.394 Hz, waktu[76] = 6.016 s
# skala[77] = 12.233 Hz, waktu[77] = 6.096 s
# skala[78] = 12.077 Hz, waktu[78] = 6.175 s
# skala[79] = 11.924 Hz, waktu[79] = 6.254 s
# skala[80] = 11.775 Hz, waktu[80] = 6.333 s
# skala[81] = 11.63 Hz, waktu[81] = 6.412 s
# skala[82] = 11.488 Hz, waktu[82] = 6.491 s
# skala[83] = 11.35 Hz, waktu[83] = 6.571 s
# skala[84] = 11.215 Hz, waktu[84] = 6.65 s
# skala[85] = 11.084 Hz, waktu[85] = 6.729 s
# skala[86] = 10.955 Hz, waktu[86] = 6.808 s
# skala[87] = 10.829 Hz, waktu[87] = 6.887 s
# skala[88] = 10.706 Hz, waktu[88] = 6.966 s
# skala[89] = 10.586 Hz, waktu[89] = 7.046 s
# skala[90] = 10.469 Hz, waktu[90] = 7.125 s
# skala[91] = 10.354 Hz, waktu[91] = 7.204 s
# skala[92] = 10.241 Hz, waktu[92] = 7.283 s
# skala[93] = 10.131 Hz, waktu[93] = 7.362 s
# skala[94] = 10.024 Hz, waktu[94] = 7.441 s
# skala[95] = 9.918 Hz, waktu[95] = 7.521 s
# skala[96] = 9.815 Hz, waktu[96] = 7.6 s
# skala[97] = 9.714 Hz, waktu[97] = 7.679 s
# skala[98] = 9.615 Hz, waktu[98] = 7.758 s
# skala[99] = 9.518 Hz, waktu[99] = 7.837 s
# skala[100] = 9.423 Hz, waktu[100] = 7.916 s
# Jumlah Sample : 63331
# frekuensi sampling: 8000
# banyaknya sample: 65008
# lama durasi: 8.126
# Loaded data shape: (65008, 2)
# Number of frames: 65008
# skala[1] = 849.0 Hz, waktu[1] = 0.081 s
# skala[2] = 446.842 Hz, waktu[2] = 0.163 s
# skala[3] = 303.214 Hz, waktu[3] = 0.244 s
# skala[4] = 229.459 Hz, waktu[4] = 0.325 s
# skala[5] = 184.565 Hz, waktu[5] = 0.406 s
# skala[6] = 154.364 Hz, waktu[6] = 0.488 s
# skala[7] = 132.656 Hz, waktu[7] = 0.569 s
# skala[8] = 116.301 Hz, waktu[8] = 0.65 s
# skala[9] = 103.537 Hz, waktu[9] = 0.731 s
# skala[10] = 93.297 Hz, waktu[10] = 0.813 s
# skala[11] = 84.9 Hz, waktu[11] = 0.894 s
# skala[12] = 77.89 Hz, waktu[12] = 0.975 s
# skala[13] = 71.949 Hz, waktu[13] = 1.056 s
# skala[14] = 66.85 Hz, waktu[14] = 1.138 s
# skala[15] = 62.426 Hz, waktu[15] = 1.219 s
# skala[16] = 58.552 Hz, waktu[16] = 1.3 s
# skala[17] = 55.13 Hz, waktu[17] = 1.381 s
# skala[18] = 52.086 Hz, waktu[18] = 1.463 s
# skala[19] = 49.36 Hz, waktu[19] = 1.544 s
# skala[20] = 46.906 Hz, waktu[20] = 1.625 s
# skala[21] = 44.684 Hz, waktu[21] = 1.706 s
# skala[22] = 42.663 Hz, waktu[22] = 1.788 s
# skala[23] = 40.817 Hz, waktu[23] = 1.869 s
# skala[24] = 39.124 Hz, waktu[24] = 1.95 s
# skala[25] = 37.566 Hz, waktu[25] = 2.031 s
# skala[26] = 36.128 Hz, waktu[26] = 2.113 s
# skala[27] = 34.795 Hz, waktu[27] = 2.194 s
# skala[28] = 33.557 Hz, waktu[28] = 2.275 s
# skala[29] = 32.405 Hz, waktu[29] = 2.357 s
# skala[30] = 31.328 Hz, waktu[30] = 2.438 s
# skala[31] = 30.321 Hz, waktu[31] = 2.519 s
# skala[32] = 29.377 Hz, waktu[32] = 2.6 s
# skala[33] = 28.49 Hz, waktu[33] = 2.682 s
# skala[34] = 27.655 Hz, waktu[34] = 2.763 s
# skala[35] = 26.867 Hz, waktu[35] = 2.844 s
# skala[36] = 26.123 Hz, waktu[36] = 2.925 s
# skala[37] = 25.419 Hz, waktu[37] = 3.007 s
# skala[38] = 24.752 Hz, waktu[38] = 3.088 s
# skala[39] = 24.119 Hz, waktu[39] = 3.169 s
# skala[40] = 23.518 Hz, waktu[40] = 3.25 s
# skala[41] = 22.946 Hz, waktu[41] = 3.332 s
# skala[42] = 22.401 Hz, waktu[42] = 3.413 s
# skala[43] = 21.881 Hz, waktu[43] = 3.494 s
# skala[44] = 21.385 Hz, waktu[44] = 3.575 s
# skala[45] = 20.911 Hz, waktu[45] = 3.657 s
# skala[46] = 20.458 Hz, waktu[46] = 3.738 s
# skala[47] = 20.024 Hz, waktu[47] = 3.819 s
# skala[48] = 19.607 Hz, waktu[48] = 3.9 s
# skala[49] = 19.208 Hz, waktu[49] = 3.982 s
# skala[50] = 18.825 Hz, waktu[50] = 4.063 s
# skala[51] = 18.457 Hz, waktu[51] = 4.144 s
# skala[52] = 18.102 Hz, waktu[52] = 4.226 s
# skala[53] = 17.762 Hz, waktu[53] = 4.307 s
# skala[54] = 17.433 Hz, waktu[54] = 4.388 s
# skala[55] = 17.117 Hz, waktu[55] = 4.469 s
# skala[56] = 16.812 Hz, waktu[56] = 4.551 s
# skala[57] = 16.518 Hz, waktu[57] = 4.632 s
# skala[58] = 16.233 Hz, waktu[58] = 4.713 s
# skala[59] = 15.959 Hz, waktu[59] = 4.794 s
# skala[60] = 15.693 Hz, waktu[60] = 4.876 s
# skala[61] = 15.436 Hz, waktu[61] = 4.957 s
# skala[62] = 15.188 Hz, waktu[62] = 5.038 s
# skala[63] = 14.947 Hz, waktu[63] = 5.119 s
# skala[64] = 14.714 Hz, waktu[64] = 5.201 s
# skala[65] = 14.488 Hz, waktu[65] = 5.282 s
# skala[66] = 14.269 Hz, waktu[66] = 5.363 s
# skala[67] = 14.056 Hz, waktu[67] = 5.444 s
# skala[68] = 13.85 Hz, waktu[68] = 5.526 s
# skala[69] = 13.65 Hz, waktu[69] = 5.607 s
# skala[70] = 13.455 Hz, waktu[70] = 5.688 s
# skala[71] = 13.266 Hz, waktu[71] = 5.769 s
# skala[72] = 13.082 Hz, waktu[72] = 5.851 s
# skala[73] = 12.903 Hz, waktu[73] = 5.932 s
# skala[74] = 12.729 Hz, waktu[74] = 6.013 s
# skala[75] = 12.559 Hz, waktu[75] = 6.094 s
# skala[76] = 12.394 Hz, waktu[76] = 6.176 s
# skala[77] = 12.233 Hz, waktu[77] = 6.257 s
# skala[78] = 12.077 Hz, waktu[78] = 6.338 s
# skala[79] = 11.924 Hz, waktu[79] = 6.42 s
# skala[80] = 11.775 Hz, waktu[80] = 6.501 s
# skala[81] = 11.63 Hz, waktu[81] = 6.582 s
# skala[82] = 11.488 Hz, waktu[82] = 6.663 s
# skala[83] = 11.35 Hz, waktu[83] = 6.745 s
# skala[84] = 11.215 Hz, waktu[84] = 6.826 s
# skala[85] = 11.084 Hz, waktu[85] = 6.907 s
# skala[86] = 10.955 Hz, waktu[86] = 6.988 s
# skala[87] = 10.829 Hz, waktu[87] = 7.07 s
# skala[88] = 10.706 Hz, waktu[88] = 7.151 s
# skala[89] = 10.586 Hz, waktu[89] = 7.232 s
# skala[90] = 10.469 Hz, waktu[90] = 7.313 s
# skala[91] = 10.354 Hz, waktu[91] = 7.395 s
# skala[92] = 10.241 Hz, waktu[92] = 7.476 s
# skala[93] = 10.131 Hz, waktu[93] = 7.557 s
# skala[94] = 10.024 Hz, waktu[94] = 7.638 s
# skala[95] = 9.918 Hz, waktu[95] = 7.72 s
# skala[96] = 9.815 Hz, waktu[96] = 7.801 s
# skala[97] = 9.714 Hz, waktu[97] = 7.882 s
# skala[98] = 9.615 Hz, waktu[98] = 7.963 s
# skala[99] = 9.518 Hz, waktu[99] = 8.045 s
# skala[100] = 9.423 Hz, waktu[100] = 8.126 s
# Jumlah Sample : 65008
